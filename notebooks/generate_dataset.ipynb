# %% [markdown]
# ## Предисловие
# Для решения различных задач видео аналитики нашей командой подготавливается датасет. Свой датасет позволить отработать возможные подходы к решению задач видеоаналитики, а также подготовить кодовую базу для обучения различных нейросетевых архитектур потенциально востребованных в решении задач такого рода.

# %% [markdown]
# ### Создание датасета формата yolo из нашей разметки

# %%
path_viame_dataset = r"G:\Мой диск\5min"
# path_viame_dataset = r"C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val"
path_yolo_dataset = r"C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\dataset_yolo_2206\bonus"

# %%
from training.dataset import ViameToYolo

accum_class = {'crane': ['high'], 'earth': ['unknown']} # high будем переводить в класс crane
name_list = ['earth', 'bobcat', 'crane', 'loader', 'truck', 'cplan'] # id будут выставлены согласно списку, и далее для новых классов
vr = ViameToYolo(path_viame_dataset, img_size_out=1280,
                 path_out_dir=path_yolo_dataset,
                 class_accumulation=accum_class,
                 class_names=name_list,
                 step_frame=10)
print("Все классы датасета:")
vr.get_all_class()
# Out:
# class_id2class_name = {0: 'earth', 1: 'bobcat', 2: 'crane', 3: 'loader', 4: 'truck'}
# Все классы датасета:
# Только имена классов до _ : {'earth', 'crane', 'loader', 'bobcat'}

# %%
import os

vr.start_processing(out_format='bbox_yolo')
print(vr.class_id2class_name)
print(list(vr.class_name2class_id), "; count =", vr.len_class)
# with open(os.path.join(path_yolo_dataset, "class_name.txt"), "w") as f:
#     print(vr.class_id2class_name, file=f)
#     print(list(vr.class_name2class_id), "; count =", vr.len_class, file=f)
# vr.get_all_class()
# Out:
# G:\Мой диск\5min\9Rc5BSwckWI_1906_03.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\9Rc5BSwckWI_1906_04.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\9Rc5BSwckWI_1906_05.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\9Rc5BSwckWI_1906_06.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\9Rc5BSwckWI_1906_07.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\9Rc5BSwckWI_1906_08.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\613iFGJm0HM_1906_01.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\613iFGJm0HM_1906_03.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\HMNa_DAVH2U_1906_02.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\HMNa_DAVH2U_1906_03.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\nKQBPEVbKYY_2106_acc_0_432000_300.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\HMNa_DAVH2U_2106_acc_0_430828_300.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\613iFGJm0HM_2106_acc_0_403176_300.mp4 пропущен т.к. нет разметки
# G:\Мой диск\5min\9Rc5BSwckWI_2106_acc_0_431856_300.mp4 пропущен т.к. нет разметки
# start reading G:\Мой диск\5min\International School of Denver Live Stream_ New Academic Building Construction (720p)_4800-5100.mp4; frames=9001.0, size=1280.0,720.0
# 100%|██████████| 9001/9001 [00:27<00:00, 331.02it/s]
# Labels created from G:\Мой диск\5min\International School of Denver Live Stream_ New Academic Building Construction (720p)_4800-5100.csv
# Обработано 15 видео из 16
# start reading G:\Мой диск\5min\International School of Denver Live Stream_ New Academic Building Construction (720p)_3600-3900.mp4; frames=9001.0, size=1280.0,720.0
# 100%|██████████| 9001/9001 [00:27<00:00, 326.06it/s]
# Labels created from G:\Мой диск\5min\International School of Denver Live Stream_ New Academic Building Construction (720p)_3600-3900.csv
# Обработано 16 видео из 16
# Finish
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import os
# ----> 3 vr.start_processing(out_format='bbox_yolo')
#       4 print(vr.class_id2class_name)
#       5 print(list(vr.class_name2class_id), "; count =", vr.len_class)
#
# File C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\dbhack-yekat\training\dataset\viame2yolo.py:307, in ViameToYolo.start_processing(self, out_format, bar, proc_image)
#     305     print(f'Обработано {i + 1} видео из {len(files)}')
#     306 print('Finish')
# --> 307 self.print_infoproc_to_file()
#
# File C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\dbhack-yekat\training\dataset\viame2yolo.py:312, in ViameToYolo.print_infoproc_to_file(self)
#     310 with open(os.path.join(self.path_out_dir, "class_name.txt"), "w") as f:
#     311     print(self.class_id2class_name, file=f)
# --> 312     print(list(self.class_name2class_id), "; count =", vr.len_class, file=f)
#
# NameError: name 'vr' is not defined
