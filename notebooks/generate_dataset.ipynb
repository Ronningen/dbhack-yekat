# %% [markdown]
# ## Предисловие
# Для решения различных задач видео аналитики нашей командой подготавливается датасет. Свой датасет позволить отработать возможные подходы к решению задач видеоаналитики, а также подготовить кодовую базу для обучения различных нейросетевых архитектур потенциально востребованных в решении задач такого рода.

# %% [markdown]
# ### Создание датасета формата yolo из нашей разметки

# %%
path_viame_dataset = r"G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup"
# path_viame_dataset = r"C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val"
path_yolo_dataset = r"C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\dataset_yolo_2206\netrics_yolo)24060208\train"

# %%
from training.dataset import ViameToYolo

# accum_class = {'crane': ['high'], 'earth': ['unknown']} # high будем переводить в класс crane
accum_class = {'crane': ['truckcrane']}
name_list = ['crane', 'earth', 'truck', 'high', 'loader', 'mixer', 'asph'] # id будут выставлены согласно списку, и далее для новых классов
vr = ViameToYolo(path_viame_dataset, img_size_out=1280,
                 path_out_dir=path_yolo_dataset,
                 class_accumulation=accum_class,
                 class_names=name_list,
                 step_frame=2)
print("Все классы датасета:")
vr.get_all_class()
# Out:
# class_id2class_name = {0: 'crane', 1: 'earth', 2: 'truck', 3: 'high', 4: 'loader', 5: 'mixer', 6: 'asph'}
# Все классы датасета:
# Только имена классов до _ : {'crane', 'earth', 'truck', 'truckcrane', 'high', 'loader', 'mixer', 'asph'}

# %%
import os

vr.start_processing(out_format='bbox_yolo')
print(vr.class_id2class_name)
print(list(vr.class_name2class_id), "; count =", vr.len_class)
# with open(os.path.join(path_yolo_dataset, "class_name.txt"), "w") as f:
#     print(vr.class_id2class_name, file=f)
#     print(list(vr.class_name2class_id), "; count =", vr.len_class, file=f)
# vr.get_all_class()
# Out:
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_0-300.mp4; frames=1800.0, size=2560.0,1440.0
#  99%|█████████▊| 1777/1800 [00:27<00:00, 65.23it/s]
# => Считаны не все кадры, 1777 из 1800.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_0-300.csv
# Обработано 1 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_1200-1500.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1800/1801 [00:27<00:00, 66.23it/s]
# => Считаны не все кадры, 1800 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_1200-1500.csv
# Обработано 2 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_2400-2700.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1799/1801 [00:27<00:00, 65.74it/s]
# => Считаны не все кадры, 1799 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_2400-2700.csv
# Обработано 3 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_3600-3900.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1798/1801 [00:27<00:00, 65.32it/s]
# => Считаны не все кадры, 1798 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_3600-3900.csv
# Обработано 4 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_4800-5100.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1797/1801 [00:27<00:00, 65.84it/s]
# => Считаны не все кадры, 1797 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_4800-5100.csv
# Обработано 5 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_6000-6300.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1796/1801 [00:27<00:00, 66.12it/s]
# => Считаны не все кадры, 1796 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_6000-6300.csv
# Обработано 6 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_7200-7500.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1795/1801 [00:26<00:00, 66.54it/s]
# => Считаны не все кадры, 1795 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_7200-7500.csv
# Обработано 7 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_8400-8700.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1794/1801 [00:26<00:00, 66.53it/s]
# => Считаны не все кадры, 1794 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_8400-8700.csv
# Обработано 8 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_13200-13500.mp4; frames=1801.0, size=2560.0,1440.0
#  99%|█████████▉| 1782/1801 [00:26<00:00, 67.06it/s]
# => Считаны не все кадры, 1782 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_13200-13500.csv
# Обработано 9 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_14400-14700.mp4; frames=1801.0, size=2560.0,1440.0
#  99%|█████████▉| 1781/1801 [00:27<00:00, 65.89it/s]
# => Считаны не все кадры, 1781 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_14400-14700.csv
# Обработано 10 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_21600-21900.mp4; frames=1801.0, size=2560.0,1440.0
# 100%|█████████▉| 1794/1801 [00:26<00:00, 66.79it/s]
# => Считаны не все кадры, 1794 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_21600-21900.csv
# Обработано 11 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_26400-26700.mp4; frames=1801.0, size=2560.0,1440.0
#  99%|█████████▉| 1790/1801 [00:26<00:00, 68.22it/s]
# => Считаны не все кадры, 1790 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_26400-26700.csv
# Обработано 12 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_30000-30300.mp4; frames=1801.0, size=2560.0,1440.0
#  99%|█████████▉| 1787/1801 [00:25<00:00, 68.99it/s]
# => Считаны не все кадры, 1787 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_30000-30300.csv
# Обработано 13 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_36000-36300.mp4; frames=1801.0, size=2560.0,1440.0
#  99%|█████████▉| 1781/1801 [00:26<00:00, 66.44it/s]
# => Считаны не все кадры, 1781 из 1801.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_36000-36300.csv
# Обработано 14 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_39600-39900.mp4; frames=1800.0, size=2560.0,1440.0
# 100%|█████████▉| 1792/1800 [00:26<00:00, 66.90it/s]
# => Считаны не все кадры, 1792 из 1800.
# Labels created from G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_39600-39900.csv
# Обработано 15 видео из 18
# start reading G:\.shortcut-targets-by-id\12eFEjs53W4IJWpGf4InEf2cT-SbM3y_s\netrics\markup\dataset_40800-41100.mp4; frames=1801.0, size=2560.0,1440.0
#  18%|█▊        | 320/1801 [00:04<00:22, 66.48it/s]
