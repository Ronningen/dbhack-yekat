# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from ultralytics import YOLO

model = YOLO('yolov8m.pt')
model.train(
    data='datasetv1.yaml',
    imgsz=1280,
    batch=5,
    cache=False,
    epochs=10,
    patience=5,
    name="attempt_2",
)

# %%
# !yolo predict model=C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\dbhack-yekat\training\yolov8\runs\detect\attempt_19\weights\best.pt source="C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4" imgsz=1280 device=cpu
# Out:
# Ultralytics YOLOv8.0.120  Python-3.9.16 torch-2.0.1+cu118 CPU
# YOLOv8m summary (fused): 218 layers, 25842655 parameters, 0 gradients
#
# video 1/1 (1/9001) C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4: 736x1280 1 loader, 978.6ms
# video 1/1 (2/9001) C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4: 736x1280 1 loader, 990.3ms
# video 1/1 (3/9001) C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4: 736x1280 1 loader, 975.0ms
# video 1/1 (4/9001) C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4: 736x1280 1 loader, 993.0ms
# video 1/1 (5/9001) C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4: 736x1280 1 loader, 1001.5ms
# video 1/1 (6/9001) C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4: 736x1280 1 loader, 1001.1ms
# ...

# %%
# yolo predict model=C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\dbhack-yekat\training\yolov8\runs\detect\attempt_19\weights\best.pt source="C:\workspace\hakaton\hak2023_Digital_breakthrough_ekat\sources\val\613iFGJm0HM_1906_04.mp4" imgsz=1280
